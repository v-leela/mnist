# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
from datasets import load_dataset

dataset = load_dataset("ylecun/mnist")
# Out:
# Generating train split: 100%|██████████| 60000/60000 [00:00<00:00, 871851.67 examples/s]
# Generating test split: 100%|██████████| 10000/10000 [00:00<00:00, 1391007.20 examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 60000
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 10000
#     })
# })

# %%
X_train = [np.array(img) for img in dataset["train"]["image"]]
y_train = list(dataset["train"]["label"])
X_test = [np.array(img) for img in dataset["test"]["image"]]
y_test = list(dataset["test"]["label"])

# %%
plt.imshow(X_train[3454], cmap="grey_r")
y_train[3454]
# Out:
# 6
